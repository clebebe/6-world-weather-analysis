# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_Database.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0      Butaritari      KI   3.0707  172.7902     81.16        76
# 1        1         Gigmoto      PH  13.7796  124.3900     82.71        79
# 2        2         Aklavik      CA  68.2191 -135.0107    -15.88        97
# 3        3       Busselton      AU -33.6500  115.3333     85.75        36
# 4        4  Cabo San Lucas      MX  22.8909 -109.9124     70.52        70
#
#    Cloudiness  Wind Speed Current Description
# 0          78       12.77       broken clouds
# 1          92        3.09     overcast clouds
# 2          92        5.41     overcast clouds
# 3           0       13.04           clear sky
# 4          60        5.01       broken clouds

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
min_temp = int(input("What is the minimum temperature you would like for your vacation? "))
max_temp = int(input("What is the maximum temperature you would like for your vacation? "))
# Out:
# What is the minimum temperature you would like for your vacation? 60
# What is the maximum temperature you would like for your vacation? 80

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)]


# Display sample data
preferred_cities_df.head(10)
# Out:
#     City_ID                          City Country      Lat       Lng  \
# 4         4                Cabo San Lucas      MX  22.8909 -109.9124
# 6         6                Port Elizabeth      ZA -33.9180   25.5701
# 8         8                      Monrovia      LR   6.3005  -10.7969
# 9         9                 Makakilo City      US  21.3469 -158.0858
# 14       14                     Cape Town      ZA -33.9258   18.4232
# 19       19                       Rikitea      PF -23.1203 -134.9692
# 20       20                Ribeira Grande      PT  38.5167  -28.7000
# 22       22                         Palpa      PE -14.5336  -75.1856
# 27       27  Presidencia Roque Saenz Pena      AR -26.7852  -60.4388
# 29       29                 Mount Gambier      AU -37.8333  140.7667
#
#     Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 4      70.52        70          60        5.01       broken clouds
# 6      69.10        67          40        5.75    scattered clouds
# 8      75.79        88          48        4.27          light rain
# 9      75.52        71         100        3.44     overcast clouds
# 14     69.12        56           0       11.01           clear sky
# 19     77.74        72          99        4.83     overcast clouds
# 20     60.78        91         100       11.99          light rain
# 22     70.93        80         100        2.98     overcast clouds
# 27     68.45        46           1        1.68           clear sky
# 29     69.44        60          28        9.40    scattered clouds

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_travel_cities = preferred_cities_df.dropna()

# Display sample data
clean_travel_cities.head(10)
# Out:
#     City_ID                          City Country      Lat       Lng  \
# 4         4                Cabo San Lucas      MX  22.8909 -109.9124
# 6         6                Port Elizabeth      ZA -33.9180   25.5701
# 8         8                      Monrovia      LR   6.3005  -10.7969
# 9         9                 Makakilo City      US  21.3469 -158.0858
# 14       14                     Cape Town      ZA -33.9258   18.4232
# 19       19                       Rikitea      PF -23.1203 -134.9692
# 20       20                Ribeira Grande      PT  38.5167  -28.7000
# 22       22                         Palpa      PE -14.5336  -75.1856
# 27       27  Presidencia Roque Saenz Pena      AR -26.7852  -60.4388
# 29       29                 Mount Gambier      AU -37.8333  140.7667
#
#     Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 4      70.52        70          60        5.01       broken clouds
# 6      69.10        67          40        5.75    scattered clouds
# 8      75.79        88          48        4.27          light rain
# 9      75.52        71         100        3.44     overcast clouds
# 14     69.12        56           0       11.01           clear sky
# 19     77.74        72          99        4.83     overcast clouds
# 20     60.78        91         100       11.99          light rain
# 22     70.93        80         100        2.98     overcast clouds
# 27     68.45        46           1        1.68           clear sky
# 29     69.44        60          28        9.40    scattered clouds

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_travel_cities.copy()
hotel_df = hotel_df[["City","Country","Max Temp","Current Description","Lat","Lng"]]
hotel_df.head(10)
# Out:
#                             City Country  Max Temp Current Description  \
# 4                 Cabo San Lucas      MX     70.52       broken clouds
# 6                 Port Elizabeth      ZA     69.10    scattered clouds
# 8                       Monrovia      LR     75.79          light rain
# 9                  Makakilo City      US     75.52     overcast clouds
# 14                     Cape Town      ZA     69.12           clear sky
# 19                       Rikitea      PF     77.74     overcast clouds
# 20                Ribeira Grande      PT     60.78          light rain
# 22                         Palpa      PE     70.93     overcast clouds
# 27  Presidencia Roque Saenz Pena      AR     68.45           clear sky
# 29                 Mount Gambier      AU     69.44    scattered clouds
#
#         Lat       Lng
# 4   22.8909 -109.9124
# 6  -33.9180   25.5701
# 8    6.3005  -10.7969
# 9   21.3469 -158.0858
# 14 -33.9258   18.4232
# 19 -23.1203 -134.9692
# 20  38.5167  -28.7000
# 22 -14.5336  -75.1856
# 27 -26.7852  -60.4388
# 29 -37.8333  140.7667

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#               City Country  Max Temp Current Description      Lat       Lng  \
# 4   Cabo San Lucas      MX     70.52       broken clouds  22.8909 -109.9124
# 6   Port Elizabeth      ZA     69.10    scattered clouds -33.9180   25.5701
# 8         Monrovia      LR     75.79          light rain   6.3005  -10.7969
# 9    Makakilo City      US     75.52     overcast clouds  21.3469 -158.0858
# 14       Cape Town      ZA     69.12           clear sky -33.9258   18.4232
#
#    Hotel Name
# 4
# 6
# 8
# 9
# 14

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = hotel_df.loc[index,"Lat"]
    longitude = hotel_df.loc[index,"Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address = requests.get(base_url,params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Cabo San Lucas - nearest hotel: Comfort Rooms
# Port Elizabeth - nearest hotel: Waterford Hotel
# Monrovia - nearest hotel: Bella Casa Hotel
# Makakilo City - nearest hotel: Embassy Suites by Hilton Oahu Kapolei
# Cape Town - nearest hotel: Townhouse Hotel
# Rikitea - nearest hotel: Chez Bianca & Benoit
# Ribeira Grande - nearest hotel: No hotel found
# Palpa - nearest hotel: Alubias
# Presidencia Roque Saenz Pena - nearest hotel: Hotel Presidente
# Mount Gambier - nearest hotel: The Old Mount Gambier Gaol
# Port Alfred - nearest hotel: No hotel found
# Tura - nearest hotel: No hotel found
# Mookane - nearest hotel: No hotel found
# Peniche - nearest hotel: Residencial Maciel
# Kitgum - nearest hotel: Cactus Hillside Hotel
# Lago Da Pedra - nearest hotel: No hotel found
# Jinotega - nearest hotel: Hotel Central
# New Norfolk - nearest hotel: Woodbridge on the Derwent
# Hobart - nearest hotel: Vibe Hotel Hobart
# Mataura - nearest hotel: No hotel found
# Oistins - nearest hotel: The Abidah By Accra
# Victoria - nearest hotel: 四季酒店 Four Seasons Hotel
# Vaini - nearest hotel: Keleti International Resort
# Itacare - nearest hotel: Pousada Raisis
# Kapaa - nearest hotel: Pono Kai Resort
# Petatlan - nearest hotel: No hotel found
# Moyo - nearest hotel: Universal Lodge Moyo
# Atuona - nearest hotel: Pearl Resort
# Montevideo - nearest hotel: Hotel Escuela
# Hilo - nearest hotel: Dolphin Bay Hotel
# Sur - nearest hotel: Sur Hotel
# Catamarca - nearest hotel: Hotel de Turismo
# Avarua - nearest hotel: Paradise Inn
# Barahona - nearest hotel: Hotel Baramar
# Dori - nearest hotel: Kuin Deni Dori
# Curuca - nearest hotel: No hotel found
# Marsa Matruh - nearest hotel: صقور
# Kahului - nearest hotel: Maui Seaside Hotel
# Manono - nearest hotel: No hotel found
# Bredasdorp - nearest hotel: Victoria Hotel
# Ambilobe - nearest hotel: Hôtel National
# Airai - nearest hotel: No hotel found
# Borda Da Mata - nearest hotel: Pousada NS da LUZ
# Pombas - nearest hotel: Aldeia Jerome
# Ciudad Guayana - nearest hotel: Hotel
# Bukama - nearest hotel: Mission catholique
# Iaciara - nearest hotel: No hotel found
# Tocopilla - nearest hotel: hotel Isidora
# Sassandra - nearest hotel: Hotel Le Pollet
# Rio De Oro - nearest hotel: Hotel santa clara
# Lithgow - nearest hotel: Grand Central Hotel
# Sao Felix Do Xingu - nearest hotel: Hotel Terraço
# Cascais - nearest hotel: Cascais Hotel
# Pangai - nearest hotel: Billy's Place
# Namibe - nearest hotel: Hotel Chik Chik Namibe
# Marsaxlokk - nearest hotel: Harbour Lodge
# Foumban - nearest hotel: Hotel Pekassa de Karché
# Gadarwara - nearest hotel: No hotel found
# Karpathos - nearest hotel: Ξενοδοχείο Τιτάνια
# Turiacu - nearest hotel: No hotel found
# Valera - nearest hotel: Valera
# Carolina - nearest hotel: No hotel found
# Salalah - nearest hotel: Muscat International Hotel
# Mecca - nearest hotel: Rehab Al Marwa Hotel 1
# Santiago Del Estero - nearest hotel: Nuevo Hotel Brístol
# Marawi - nearest hotel: Marawi Resort Hotel
# Cururupu - nearest hotel: No hotel found
# Kaeo - nearest hotel: No hotel found
# San Juan - nearest hotel: Hotel San Francisco
# Mumbwa - nearest hotel: La Hacienda
# Coolum Beach - nearest hotel: No hotel found
# Acapulco - nearest hotel: Hotel del Valle
# Gao - nearest hotel: No hotel found
# San Luis - nearest hotel: Hotel Dos Venados
# Cervo - nearest hotel: Hotel Spa Galatea
# Obidos - nearest hotel: Hotel Brás Belo
# Itoman - nearest hotel: No hotel found
# Padre Paraiso - nearest hotel: No hotel found
# Celestun - nearest hotel: Hotel Flamingo Playa
# Lucapa - nearest hotel: No hotel found
# Atar - nearest hotel: فندق سكليل
# Barranca - nearest hotel: Emperador
# Valparaiso - nearest hotel: Ibis Hotel
# Hualmay - nearest hotel: Hotel Mi Choacan
# Huarmey - nearest hotel: Hostal Santa Rosa
# Kasama - nearest hotel: No hotel found
# Nishihara - nearest hotel: ユインチホテル南城
# Vilhena - nearest hotel: No hotel found
# Kidal - nearest hotel: No hotel found
# Canning - nearest hotel: No hotel found
# Taltal - nearest hotel: Hostería Taltal
# Sao Luiz Gonzaga - nearest hotel: Cometa Plaza Hotel
# Siyabuswa - nearest hotel: No hotel found
# Grand-Santi - nearest hotel: No hotel found
# Nhulunbuy - nearest hotel: No hotel found
# Wukari - nearest hotel: No hotel found
# San Cristobal - nearest hotel: Terra Sur
# Menongue - nearest hotel: No hotel found
# Acara - nearest hotel: No hotel found
# Burnie - nearest hotel: Burnie Central TownHouse Hotel
# Puerto Del Rosario - nearest hotel: Hotel Tamasite
# Natitingou - nearest hotel: CPNO
# Lai - nearest hotel: Auberge Shalom de Laï
# Kimbe - nearest hotel: Kimbe Bay Hotel
# Escarcega - nearest hotel: Ah Kim Pech
# Pereira Barreto - nearest hotel: Rota Hotel
# Maragogi - nearest hotel: Pousada Mariluz
# Mulege - nearest hotel: Hacienda Hotel
# Devonport - nearest hotel: Elimatta Hotel
# Aden - nearest hotel: فندق قصر الجزيرة
# Bonfim - nearest hotel: No hotel found
# Te Anau - nearest hotel: Lakeside Motels & Apartments
# Vredendal - nearest hotel: No hotel found
# Santo Andre - nearest hotel: Plaza Mayor
# La Ligua - nearest hotel: Hotel Anchimallen
# Piopio - nearest hotel: No hotel found
# Isla Mujeres - nearest hotel: Villa La Bella
# Harrison - nearest hotel: Residence Inn
#                City Country  Max Temp Current Description      Lat       Lng  \
# 4    Cabo San Lucas      MX     70.52       broken clouds  22.8909 -109.9124
# 6    Port Elizabeth      ZA     69.10    scattered clouds -33.9180   25.5701
# 8          Monrovia      LR     75.79          light rain   6.3005  -10.7969
# 9     Makakilo City      US     75.52     overcast clouds  21.3469 -158.0858
# 14        Cape Town      ZA     69.12           clear sky -33.9258   18.4232
# ..              ...     ...       ...                 ...      ...       ...
# 730     Santo Andre      BR     67.57     overcast clouds -23.6639  -46.5383
# 734        La Ligua      CL     61.27           clear sky -32.4524  -71.2311
# 737          Piopio      NZ     71.10           clear sky -38.4667  175.0167
# 739    Isla Mujeres      MX     77.16          light rain  21.2311  -86.7310
# 740        Harrison      US     66.76     overcast clouds  30.4091  -89.0436
#
#                                 Hotel Name
# 4                            Comfort Rooms
# 6                          Waterford Hotel
# 8                         Bella Casa Hotel
# 9    Embassy Suites by Hilton Oahu Kapolei
# 14                         Townhouse Hotel
# ..                                     ...
# 730                            Plaza Mayor
# 734                      Hotel Anchimallen
# 737                         No hotel found
# 739                         Villa La Bella
# 740                          Residence Inn
#
# [254 rows x 7 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.loc[hotel_df["Hotel Name"] != "No hotel found"]

# Display sample data
clean_hotel_df.head(10)
# Out:
#                             City Country  Max Temp Current Description  \
# 4                 Cabo San Lucas      MX     70.52       broken clouds
# 6                 Port Elizabeth      ZA     69.10    scattered clouds
# 8                       Monrovia      LR     75.79          light rain
# 9                  Makakilo City      US     75.52     overcast clouds
# 14                     Cape Town      ZA     69.12           clear sky
# 19                       Rikitea      PF     77.74     overcast clouds
# 22                         Palpa      PE     70.93     overcast clouds
# 27  Presidencia Roque Saenz Pena      AR     68.45           clear sky
# 29                 Mount Gambier      AU     69.44    scattered clouds
# 36                       Peniche      PT     62.29     overcast clouds
#
#         Lat       Lng                             Hotel Name
# 4   22.8909 -109.9124                          Comfort Rooms
# 6  -33.9180   25.5701                        Waterford Hotel
# 8    6.3005  -10.7969                       Bella Casa Hotel
# 9   21.3469 -158.0858  Embassy Suites by Hilton Oahu Kapolei
# 14 -33.9258   18.4232                        Townhouse Hotel
# 19 -23.1203 -134.9692                   Chez Bianca & Benoit
# 22 -14.5336  -75.1856                                Alubias
# 27 -26.7852  -60.4388                       Hotel Presidente
# 29 -37.8333  140.7667             The Old Mount Gambier Gaol
# 36  39.3558   -9.3811                     Residencial Maciel

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
output_file = "WeatherPy_vacation.csv"

# Export the City_Data into a csv
clean_hotel_df.to_csv(output_file, index_label = "City ID")

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot
hotel_map = clean_hotel_df.hvplot.points("Lng",
                                         "Lat",
                                         hover_cols=["Country","Hotel Name","Current Description"],
                                         geo=True,
                                         tiles="OSM",
                                         size='Max Temp',
                                         scale=1,
                                         color="City",
                                         frame_width=700,
                                         frame_height=500)
# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Country,Hotel Name,Current Description)
