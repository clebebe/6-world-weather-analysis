# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 737

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descrip = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Weather Description": city_descrip})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | gigmoto
# Processing Record 3 of Set 1 | aklavik
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | cabo san lucas
# Processing Record 6 of Set 1 | prince rupert
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | hithadhoo
# Processing Record 9 of Set 1 | monrovia
# Processing Record 10 of Set 1 | makakilo city
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | mahebourg
# Processing Record 13 of Set 1 | ukiah
# Processing Record 14 of Set 1 | provideniya
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | moses lake
# Processing Record 17 of Set 1 | lavrentiya
# Processing Record 18 of Set 1 | yulara
# Processing Record 19 of Set 1 | noyabrsk
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | sioux lookout
# Processing Record 23 of Set 1 | palpa
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | kysyl-syr
# Processing Record 27 of Set 1 | denpasar
# Processing Record 28 of Set 1 | presidencia roque saenz pena
# Processing Record 29 of Set 1 | bilma
# Processing Record 30 of Set 1 | mount gambier
# Processing Record 31 of Set 1 | pittsburg
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | tura
# Processing Record 34 of Set 1 | berdigestyakh
# Processing Record 35 of Set 1 | khatanga
# Processing Record 36 of Set 1 | mookane
# Processing Record 37 of Set 1 | peniche
# Processing Record 38 of Set 1 | karlskoga
# Processing Record 39 of Set 1 | asau
# Processing Record 40 of Set 1 | kitgum
# Processing Record 41 of Set 1 | lago da pedra
# Processing Record 42 of Set 1 | jinotega
# Processing Record 43 of Set 1 | evensk
# Processing Record 44 of Set 1 | new norfolk
# Processing Record 45 of Set 1 | jahrom
# City not found. Skipping...
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | hofn
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | mount isa
# Processing Record 50 of Set 1 | baiyin
# Processing Record 1 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 2 of Set 2 | baykit
# Processing Record 3 of Set 2 | oistins
# Processing Record 4 of Set 2 | karakendzha
# City not found. Skipping...
# Processing Record 5 of Set 2 | victoria
# Processing Record 6 of Set 2 | norman wells
# Processing Record 7 of Set 2 | tuatapere
# Processing Record 8 of Set 2 | parry sound
# Processing Record 9 of Set 2 | isangel
# Processing Record 10 of Set 2 | ambovombe
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | poretskoye
# Processing Record 14 of Set 2 | vitim
# Processing Record 15 of Set 2 | itacare
# Processing Record 16 of Set 2 | martapura
# Processing Record 17 of Set 2 | kapaa
# Processing Record 18 of Set 2 | kavieng
# Processing Record 19 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 20 of Set 2 | hasaki
# Processing Record 21 of Set 2 | torbay
# Processing Record 22 of Set 2 | petatlan
# Processing Record 23 of Set 2 | moyo
# Processing Record 24 of Set 2 | atuona
# Processing Record 25 of Set 2 | severo-kurilsk
# Processing Record 26 of Set 2 | georgetown
# Processing Record 27 of Set 2 | montevideo
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | sur
# Processing Record 30 of Set 2 | catamarca
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | guerrero negro
# Processing Record 34 of Set 2 | avarua
# Processing Record 35 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 2 | palmer
# Processing Record 37 of Set 2 | barahona
# Processing Record 38 of Set 2 | dori
# Processing Record 39 of Set 2 | loyga
# Processing Record 40 of Set 2 | curuca
# Processing Record 41 of Set 2 | castro
# Processing Record 42 of Set 2 | marsa matruh
# Processing Record 43 of Set 2 | rio gallegos
# Processing Record 44 of Set 2 | luwuk
# Processing Record 45 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 2 | nome
# Processing Record 48 of Set 2 | kaitangata
# Processing Record 49 of Set 2 | kahului
# Processing Record 50 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | hongjiang
# Processing Record 3 of Set 3 | kachug
# Processing Record 4 of Set 3 | manono
# Processing Record 5 of Set 3 | ostrovnoy
# Processing Record 6 of Set 3 | coihaique
# Processing Record 7 of Set 3 | batagay-alyta
# Processing Record 8 of Set 3 | nikolskoye
# Processing Record 9 of Set 3 | alofi
# Processing Record 10 of Set 3 | dingle
# Processing Record 11 of Set 3 | floro
# Processing Record 12 of Set 3 | tuktoyaktuk
# Processing Record 13 of Set 3 | bredasdorp
# Processing Record 14 of Set 3 | verkh-usugli
# Processing Record 15 of Set 3 | ornes
# Processing Record 16 of Set 3 | ambilobe
# Processing Record 17 of Set 3 | thompson
# Processing Record 18 of Set 3 | springdale
# Processing Record 19 of Set 3 | airai
# Processing Record 20 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 3 | kutum
# Processing Record 22 of Set 3 | jiuquan
# Processing Record 23 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 3 | cockburn town
# Processing Record 25 of Set 3 | cidreira
# Processing Record 26 of Set 3 | komsomolskiy
# Processing Record 27 of Set 3 | sitka
# Processing Record 28 of Set 3 | tasiilaq
# Processing Record 29 of Set 3 | pangnirtung
# Processing Record 30 of Set 3 | tierralta
# Processing Record 31 of Set 3 | vytegra
# Processing Record 32 of Set 3 | bambous virieux
# Processing Record 33 of Set 3 | qaanaaq
# Processing Record 34 of Set 3 | ossora
# Processing Record 35 of Set 3 | wanning
# Processing Record 36 of Set 3 | manicore
# Processing Record 37 of Set 3 | kasongo-lunda
# Processing Record 38 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 3 | kvarkeno
# Processing Record 40 of Set 3 | vostok
# Processing Record 41 of Set 3 | atmakur
# Processing Record 42 of Set 3 | bungu
# Processing Record 43 of Set 3 | lichtenburg
# Processing Record 44 of Set 3 | bengkulu
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | arraial do cabo
# Processing Record 47 of Set 3 | port lincoln
# Processing Record 48 of Set 3 | berezovyy
# Processing Record 49 of Set 3 | puerto ayora
# Processing Record 50 of Set 3 | ulaangom
# Processing Record 1 of Set 4 | el doncello
# Processing Record 2 of Set 4 | aguilas
# Processing Record 3 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 4 of Set 4 | hermanus
# Processing Record 5 of Set 4 | molokovo
# Processing Record 6 of Set 4 | kuala terengganu
# Processing Record 7 of Set 4 | tiarei
# Processing Record 8 of Set 4 | muisne
# Processing Record 9 of Set 4 | piacabucu
# Processing Record 10 of Set 4 | bluff
# Processing Record 11 of Set 4 | dangara
# Processing Record 12 of Set 4 | antofagasta
# Processing Record 13 of Set 4 | longyearbyen
# Processing Record 14 of Set 4 | muros
# Processing Record 15 of Set 4 | garden city
# Processing Record 16 of Set 4 | cherskiy
# Processing Record 17 of Set 4 | saldanha
# Processing Record 18 of Set 4 | tiksi
# Processing Record 19 of Set 4 | tansen
# Processing Record 20 of Set 4 | verkhoyansk
# Processing Record 21 of Set 4 | dien bien
# City not found. Skipping...
# Processing Record 22 of Set 4 | saint-philippe
# Processing Record 23 of Set 4 | jhang
# Processing Record 24 of Set 4 | thunder bay
# Processing Record 25 of Set 4 | sakakah
# Processing Record 26 of Set 4 | ponta do sol
# Processing Record 27 of Set 4 | pudozh
# Processing Record 28 of Set 4 | simao
# Processing Record 29 of Set 4 | biak
# Processing Record 30 of Set 4 | reggio di calabria
# Processing Record 31 of Set 4 | roald
# Processing Record 32 of Set 4 | malaya serdoba
# Processing Record 33 of Set 4 | coquimbo
# Processing Record 34 of Set 4 | turukhansk
# Processing Record 35 of Set 4 | diamantino
# Processing Record 36 of Set 4 | goderich
# Processing Record 37 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 4 | lata
# Processing Record 39 of Set 4 | pipri
# Processing Record 40 of Set 4 | mayo
# Processing Record 41 of Set 4 | qaqortoq
# Processing Record 42 of Set 4 | khani
# Processing Record 43 of Set 4 | agadir
# Processing Record 44 of Set 4 | saskylakh
# Processing Record 45 of Set 4 | taoudenni
# Processing Record 46 of Set 4 | athabasca
# Processing Record 47 of Set 4 | bethel
# Processing Record 48 of Set 4 | iralaya
# Processing Record 49 of Set 4 | tabou
# Processing Record 50 of Set 4 | doha
# Processing Record 1 of Set 5 | poum
# Processing Record 2 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 5 | maniitsoq
# Processing Record 4 of Set 5 | clyde river
# Processing Record 5 of Set 5 | fukue
# Processing Record 6 of Set 5 | usinsk
# Processing Record 7 of Set 5 | qeshm
# Processing Record 8 of Set 5 | rangpur
# Processing Record 9 of Set 5 | aksarka
# Processing Record 10 of Set 5 | erdenet
# Processing Record 11 of Set 5 | nouadhibou
# Processing Record 12 of Set 5 | tual
# Processing Record 13 of Set 5 | vao
# Processing Record 14 of Set 5 | chokurdakh
# Processing Record 15 of Set 5 | aitape
# Processing Record 16 of Set 5 | kenai
# Processing Record 17 of Set 5 | hervey bay
# Processing Record 18 of Set 5 | tingrela
# City not found. Skipping...
# Processing Record 19 of Set 5 | zeya
# Processing Record 20 of Set 5 | high level
# Processing Record 21 of Set 5 | saint-pierre
# Processing Record 22 of Set 5 | necochea
# Processing Record 23 of Set 5 | nagato
# Processing Record 24 of Set 5 | skibbereen
# Processing Record 25 of Set 5 | san jose de guanipa
# Processing Record 26 of Set 5 | kalisz
# Processing Record 27 of Set 5 | nalut
# Processing Record 28 of Set 5 | kurumkan
# Processing Record 29 of Set 5 | kottapalli
# Processing Record 30 of Set 5 | lompoc
# Processing Record 31 of Set 5 | morant bay
# Processing Record 32 of Set 5 | tigzirt
# Processing Record 33 of Set 5 | yar-sale
# Processing Record 34 of Set 5 | lerwick
# Processing Record 35 of Set 5 | iqaluit
# Processing Record 36 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 5 | tuyen quang
# Processing Record 38 of Set 5 | jacareacanga
# Processing Record 39 of Set 5 | ahtopol
# Processing Record 40 of Set 5 | west bay
# Processing Record 41 of Set 5 | songjianghe
# Processing Record 42 of Set 5 | flinders
# Processing Record 43 of Set 5 | antonio escobedo
# Processing Record 44 of Set 5 | kavaratti
# Processing Record 45 of Set 5 | kruisfontein
# Processing Record 46 of Set 5 | havelock
# Processing Record 47 of Set 5 | talnakh
# Processing Record 48 of Set 5 | sistranda
# Processing Record 49 of Set 5 | aljezur
# Processing Record 50 of Set 5 | lamidan
# City not found. Skipping...
# Processing Record 1 of Set 6 | ushtobe
# Processing Record 2 of Set 6 | antalaha
# Processing Record 3 of Set 6 | sorland
# Processing Record 4 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 5 of Set 6 | kudahuvadhoo
# Processing Record 6 of Set 6 | dunedin
# Processing Record 7 of Set 6 | faanui
# Processing Record 8 of Set 6 | kungalv
# Processing Record 9 of Set 6 | cermik
# Processing Record 10 of Set 6 | ixtapa
# Processing Record 11 of Set 6 | caranavi
# Processing Record 12 of Set 6 | adrar
# Processing Record 13 of Set 6 | chernyshevskiy
# Processing Record 14 of Set 6 | kalmunai
# Processing Record 15 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 6 | santa cruz cabralia
# Processing Record 17 of Set 6 | weihe
# Processing Record 18 of Set 6 | kirakira
# Processing Record 19 of Set 6 | olinda
# Processing Record 20 of Set 6 | charters towers
# Processing Record 21 of Set 6 | surt
# Processing Record 22 of Set 6 | sola
# Processing Record 23 of Set 6 | mitsamiouli
# Processing Record 24 of Set 6 | cap malheureux
# Processing Record 25 of Set 6 | chernaya kholunitsa
# Processing Record 26 of Set 6 | phalaborwa
# Processing Record 27 of Set 6 | olavarria
# Processing Record 28 of Set 6 | ahuimanu
# Processing Record 29 of Set 6 | trunovskoye
# Processing Record 30 of Set 6 | maningrida
# Processing Record 31 of Set 6 | matagami
# Processing Record 32 of Set 6 | gat
# Processing Record 33 of Set 6 | lyndon
# Processing Record 34 of Set 6 | san lorenzo
# Processing Record 35 of Set 6 | benjamin hill
# Processing Record 36 of Set 6 | sayyan
# Processing Record 37 of Set 6 | dianopolis
# City not found. Skipping...
# Processing Record 38 of Set 6 | harper
# Processing Record 39 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 6 | la rioja
# Processing Record 42 of Set 6 | nanortalik
# Processing Record 43 of Set 6 | east london
# Processing Record 44 of Set 6 | chifeng
# Processing Record 45 of Set 6 | lukulu
# Processing Record 46 of Set 6 | rocha
# Processing Record 47 of Set 6 | ilulissat
# Processing Record 48 of Set 6 | hukuntsi
# Processing Record 49 of Set 6 | tartagal
# Processing Record 50 of Set 6 | anloga
# Processing Record 1 of Set 7 | raga
# Processing Record 2 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 3 of Set 7 | pasni
# Processing Record 4 of Set 7 | kenora
# Processing Record 5 of Set 7 | pacific grove
# Processing Record 6 of Set 7 | sao joao da barra
# Processing Record 7 of Set 7 | san patricio
# Processing Record 8 of Set 7 | kodiak
# Processing Record 9 of Set 7 | solnechnyy
# Processing Record 10 of Set 7 | russell
# Processing Record 11 of Set 7 | san policarpo
# Processing Record 12 of Set 7 | bilibino
# Processing Record 13 of Set 7 | carnarvon
# Processing Record 14 of Set 7 | sibolga
# Processing Record 15 of Set 7 | saint anthony
# Processing Record 16 of Set 7 | tarapur
# Processing Record 17 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 7 | auki
# Processing Record 19 of Set 7 | carutapera
# Processing Record 20 of Set 7 | buala
# Processing Record 21 of Set 7 | zhigansk
# Processing Record 22 of Set 7 | awbari
# Processing Record 23 of Set 7 | lubango
# Processing Record 24 of Set 7 | naze
# Processing Record 25 of Set 7 | itupiranga
# Processing Record 26 of Set 7 | igrim
# Processing Record 27 of Set 7 | butembo
# Processing Record 28 of Set 7 | mus
# Processing Record 29 of Set 7 | constitucion
# Processing Record 30 of Set 7 | hami
# Processing Record 31 of Set 7 | manokwari
# Processing Record 32 of Set 7 | leninskoye
# Processing Record 33 of Set 7 | esperance
# Processing Record 34 of Set 7 | sabha
# Processing Record 35 of Set 7 | praya
# Processing Record 36 of Set 7 | san-pedro
# Processing Record 37 of Set 7 | ketchikan
# Processing Record 38 of Set 7 | azimur
# City not found. Skipping...
# Processing Record 39 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 7 | lagoa
# Processing Record 41 of Set 7 | svetlyy
# Processing Record 42 of Set 7 | ugoofaaru
# Processing Record 43 of Set 7 | bac lieu
# Processing Record 44 of Set 7 | maidens
# Processing Record 45 of Set 7 | aksu
# Processing Record 46 of Set 7 | iquique
# Processing Record 47 of Set 7 | chiria
# Processing Record 48 of Set 7 | vila velha
# Processing Record 49 of Set 7 | bereda
# Processing Record 50 of Set 7 | wuda
# Processing Record 1 of Set 8 | polunochnoye
# Processing Record 2 of Set 8 | bennettsville
# Processing Record 3 of Set 8 | olafsvik
# Processing Record 4 of Set 8 | neiafu
# Processing Record 5 of Set 8 | aripuana
# Processing Record 6 of Set 8 | korla
# Processing Record 7 of Set 8 | tabuk
# Processing Record 8 of Set 8 | tumpat
# Processing Record 9 of Set 8 | rumoi
# Processing Record 10 of Set 8 | kunigal
# Processing Record 11 of Set 8 | mazabuka
# Processing Record 12 of Set 8 | gravdal
# Processing Record 13 of Set 8 | uray
# Processing Record 14 of Set 8 | salamanca
# Processing Record 15 of Set 8 | rock springs
# Processing Record 16 of Set 8 | kalga
# Processing Record 17 of Set 8 | upernavik
# Processing Record 18 of Set 8 | maraa
# Processing Record 19 of Set 8 | nara
# Processing Record 20 of Set 8 | mzimba
# Processing Record 21 of Set 8 | la palma
# Processing Record 22 of Set 8 | kokorevka
# Processing Record 23 of Set 8 | leningradskiy
# Processing Record 24 of Set 8 | port blair
# Processing Record 25 of Set 8 | serebryansk
# Processing Record 26 of Set 8 | puerto leguizamo
# Processing Record 27 of Set 8 | chumphon
# Processing Record 28 of Set 8 | dzaoudzi
# Processing Record 29 of Set 8 | tecoanapa
# Processing Record 30 of Set 8 | roebourne
# Processing Record 31 of Set 8 | sisimiut
# Processing Record 32 of Set 8 | westport
# Processing Record 33 of Set 8 | lima
# Processing Record 34 of Set 8 | maldonado
# Processing Record 35 of Set 8 | kununurra
# Processing Record 36 of Set 8 | inhambane
# Processing Record 37 of Set 8 | guymon
# Processing Record 38 of Set 8 | sao manuel
# Processing Record 39 of Set 8 | tezu
# Processing Record 40 of Set 8 | campbell river
# Processing Record 41 of Set 8 | touros
# Processing Record 42 of Set 8 | jand
# Processing Record 43 of Set 8 | shitanjing
# Processing Record 44 of Set 8 | dauphin
# Processing Record 45 of Set 8 | pottsville
# Processing Record 46 of Set 8 | puerto escondido
# Processing Record 47 of Set 8 | pisco
# Processing Record 48 of Set 8 | badulla
# Processing Record 49 of Set 8 | atasu
# Processing Record 50 of Set 8 | katherine
# Processing Record 1 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 2 of Set 9 | christchurch
# Processing Record 3 of Set 9 | coronado
# Processing Record 4 of Set 9 | ancud
# Processing Record 5 of Set 9 | azar shahr
# City not found. Skipping...
# Processing Record 6 of Set 9 | morondava
# Processing Record 7 of Set 9 | saquarema
# Processing Record 8 of Set 9 | altamont
# Processing Record 9 of Set 9 | shetpe
# Processing Record 10 of Set 9 | basco
# Processing Record 11 of Set 9 | sao filipe
# Processing Record 12 of Set 9 | san rafael
# Processing Record 13 of Set 9 | kolochava
# Processing Record 14 of Set 9 | jertih
# Processing Record 15 of Set 9 | bandar
# Processing Record 16 of Set 9 | xaxim
# Processing Record 17 of Set 9 | umm lajj
# Processing Record 18 of Set 9 | chuy
# Processing Record 19 of Set 9 | kyshtovka
# Processing Record 20 of Set 9 | susehri
# Processing Record 21 of Set 9 | port shepstone
# Processing Record 22 of Set 9 | bend
# Processing Record 23 of Set 9 | bonavista
# Processing Record 24 of Set 9 | astana
# Processing Record 25 of Set 9 | porec
# Processing Record 26 of Set 9 | lyngseidet
# Processing Record 27 of Set 9 | calafell
# Processing Record 28 of Set 9 | agfalva
# Processing Record 29 of Set 9 | geraldton
# Processing Record 30 of Set 9 | richards bay
# Processing Record 31 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 32 of Set 9 | challans
# Processing Record 33 of Set 9 | los llanos de aridane
# Processing Record 34 of Set 9 | hamilton
# Processing Record 35 of Set 9 | broken hill
# Processing Record 36 of Set 9 | lorengau
# Processing Record 37 of Set 9 | mitu
# Processing Record 38 of Set 9 | boddam
# Processing Record 39 of Set 9 | loandjili
# Processing Record 40 of Set 9 | spring valley
# Processing Record 41 of Set 9 | mwense
# Processing Record 42 of Set 9 | mantua
# Processing Record 43 of Set 9 | west wendover
# Processing Record 44 of Set 9 | luena
# Processing Record 45 of Set 9 | gusev
# Processing Record 46 of Set 9 | canto do buriti
# Processing Record 47 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 48 of Set 9 | nam som
# Processing Record 49 of Set 9 | vestmanna
# Processing Record 50 of Set 9 | cayenne
# Processing Record 1 of Set 10 | soyo
# Processing Record 2 of Set 10 | souillac
# Processing Record 3 of Set 10 | pagudpud
# Processing Record 4 of Set 10 | brownsville
# Processing Record 5 of Set 10 | waddan
# Processing Record 6 of Set 10 | eydhafushi
# Processing Record 7 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 10 | ada
# Processing Record 9 of Set 10 | alice springs
# Processing Record 10 of Set 10 | apatzingan
# Processing Record 11 of Set 10 | aginskoye
# Processing Record 12 of Set 10 | batemans bay
# Processing Record 13 of Set 10 | nata
# Processing Record 14 of Set 10 | acurenam
# Processing Record 15 of Set 10 | derzhavinsk
# Processing Record 16 of Set 10 | kisangani
# Processing Record 17 of Set 10 | palu
# Processing Record 18 of Set 10 | altay
# Processing Record 19 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 20 of Set 10 | mendeleyevsk
# Processing Record 21 of Set 10 | guanhaes
# Processing Record 22 of Set 10 | yining
# Processing Record 23 of Set 10 | rawson
# Processing Record 24 of Set 10 | nantucket
# Processing Record 25 of Set 10 | linxia
# Processing Record 26 of Set 10 | neuquen
# Processing Record 27 of Set 10 | nabire
# Processing Record 28 of Set 10 | portland
# Processing Record 29 of Set 10 | pravokumskoye
# Processing Record 30 of Set 10 | berbera
# Processing Record 31 of Set 10 | avera
# Processing Record 32 of Set 10 | chimbarongo
# Processing Record 33 of Set 10 | haikou
# Processing Record 34 of Set 10 | gijon
# Processing Record 35 of Set 10 | novyy oskol
# Processing Record 36 of Set 10 | quatre cocos
# Processing Record 37 of Set 10 | muroto
# Processing Record 38 of Set 10 | pousat
# City not found. Skipping...
# Processing Record 39 of Set 10 | wonji
# City not found. Skipping...
# Processing Record 40 of Set 10 | katesh
# Processing Record 41 of Set 10 | yarkovo
# Processing Record 42 of Set 10 | kharan
# Processing Record 43 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 10 | mwinilunga
# Processing Record 45 of Set 10 | shingu
# Processing Record 46 of Set 10 | bonthe
# Processing Record 47 of Set 10 | narsaq
# Processing Record 48 of Set 10 | faya
# Processing Record 49 of Set 10 | mathbaria
# Processing Record 50 of Set 10 | codrington
# Processing Record 1 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 2 of Set 11 | fagersta
# Processing Record 3 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 4 of Set 11 | tamsweg
# Processing Record 5 of Set 11 | tranas
# Processing Record 6 of Set 11 | delta del tigre
# Processing Record 7 of Set 11 | noumea
# Processing Record 8 of Set 11 | saint george
# Processing Record 9 of Set 11 | urumqi
# Processing Record 10 of Set 11 | mar del plata
# Processing Record 11 of Set 11 | ca mau
# Processing Record 12 of Set 11 | anadyr
# Processing Record 13 of Set 11 | dudinka
# Processing Record 14 of Set 11 | megion
# Processing Record 15 of Set 11 | marsh harbour
# Processing Record 16 of Set 11 | riberalta
# Processing Record 17 of Set 11 | kijang
# Processing Record 18 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 11 | montepuez
# Processing Record 20 of Set 11 | tiznit
# Processing Record 21 of Set 11 | vista hermosa
# Processing Record 22 of Set 11 | chunskiy
# Processing Record 23 of Set 11 | moorhead
# Processing Record 24 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 11 | darhan
# Processing Record 26 of Set 11 | catalina
# Processing Record 27 of Set 11 | luderitz
# Processing Record 28 of Set 11 | olesnica
# Processing Record 29 of Set 11 | waipawa
# Processing Record 30 of Set 11 | buraydah
# Processing Record 31 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 11 | sheregesh
# Processing Record 33 of Set 11 | bonoua
# Processing Record 34 of Set 11 | kovylkino
# Processing Record 35 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 36 of Set 11 | krasnoarmeysk
# Processing Record 37 of Set 11 | namanga
# Processing Record 38 of Set 11 | keetmanshoop
# Processing Record 39 of Set 11 | jalu
# Processing Record 40 of Set 11 | yerbogachen
# Processing Record 41 of Set 11 | srednekolymsk
# Processing Record 42 of Set 11 | caravelas
# Processing Record 43 of Set 11 | pokhara
# Processing Record 44 of Set 11 | dwarka
# Processing Record 45 of Set 11 | urusha
# Processing Record 46 of Set 11 | beringovskiy
# Processing Record 47 of Set 11 | mingyue
# Processing Record 48 of Set 11 | san andres
# Processing Record 49 of Set 11 | marzuq
# Processing Record 50 of Set 11 | manzil tamim
# City not found. Skipping...
# Processing Record 1 of Set 12 | pochutla
# Processing Record 2 of Set 12 | nemuro
# Processing Record 3 of Set 12 | deputatskiy
# Processing Record 4 of Set 12 | atambua
# Processing Record 5 of Set 12 | adamas
# Processing Record 6 of Set 12 | aosta
# Processing Record 7 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 12 | thongwa
# Processing Record 9 of Set 12 | katete
# Processing Record 10 of Set 12 | calmar
# Processing Record 11 of Set 12 | borda da mata
# Processing Record 12 of Set 12 | beloha
# Processing Record 13 of Set 12 | negombo
# Processing Record 14 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 15 of Set 12 | pombas
# Processing Record 16 of Set 12 | troitskoye
# Processing Record 17 of Set 12 | husavik
# Processing Record 18 of Set 12 | nakamura
# Processing Record 19 of Set 12 | mirnyy
# Processing Record 20 of Set 12 | ciudad guayana
# Processing Record 21 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 12 | mehamn
# Processing Record 23 of Set 12 | strezhevoy
# Processing Record 24 of Set 12 | severodvinsk
# Processing Record 25 of Set 12 | dukat
# Processing Record 26 of Set 12 | wenatchee
# Processing Record 27 of Set 12 | staunton
# Processing Record 28 of Set 12 | tautira
# Processing Record 29 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 30 of Set 12 | millinocket
# Processing Record 31 of Set 12 | bukama
# Processing Record 32 of Set 12 | iaciara
# Processing Record 33 of Set 12 | tocopilla
# Processing Record 34 of Set 12 | kapoeta
# Processing Record 35 of Set 12 | charcas
# Processing Record 36 of Set 12 | pevek
# Processing Record 37 of Set 12 | sassandra
# Processing Record 38 of Set 12 | rio de oro
# Processing Record 39 of Set 12 | lincoln
# Processing Record 40 of Set 12 | kuytun
# Processing Record 41 of Set 12 | padang
# Processing Record 42 of Set 12 | lithgow
# Processing Record 43 of Set 12 | sao felix do xingu
# Processing Record 44 of Set 12 | khash
# Processing Record 45 of Set 12 | flin flon
# Processing Record 46 of Set 12 | laguna
# Processing Record 47 of Set 12 | honiara
# Processing Record 48 of Set 12 | cascais
# Processing Record 49 of Set 12 | hailar
# Processing Record 50 of Set 12 | shibetsu
# Processing Record 1 of Set 13 | pangai
# Processing Record 2 of Set 13 | namibe
# Processing Record 3 of Set 13 | vestmannaeyjar
# Processing Record 4 of Set 13 | wilmington
# Processing Record 5 of Set 13 | fairbanks
# Processing Record 6 of Set 13 | marsaxlokk
# Processing Record 7 of Set 13 | foumban
# Processing Record 8 of Set 13 | dhidhdhoo
# Processing Record 9 of Set 13 | aykhal
# Processing Record 10 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 11 of Set 13 | elko
# Processing Record 12 of Set 13 | half moon bay
# Processing Record 13 of Set 13 | gadarwara
# Processing Record 14 of Set 13 | simbahan
# Processing Record 15 of Set 13 | lamont
# Processing Record 16 of Set 13 | ayan
# Processing Record 17 of Set 13 | karpathos
# Processing Record 18 of Set 13 | timmendorfer strand
# Processing Record 19 of Set 13 | alekseyevka
# Processing Record 20 of Set 13 | amparai
# City not found. Skipping...
# Processing Record 21 of Set 13 | la esperanza
# Processing Record 22 of Set 13 | karymskoye
# Processing Record 23 of Set 13 | snasa
# Processing Record 24 of Set 13 | turiacu
# Processing Record 25 of Set 13 | valera
# Processing Record 26 of Set 13 | klaksvik
# Processing Record 27 of Set 13 | swan river
# Processing Record 28 of Set 13 | oktyabrskiy
# Processing Record 29 of Set 13 | quincy
# Processing Record 30 of Set 13 | omboue
# Processing Record 31 of Set 13 | carolina
# Processing Record 32 of Set 13 | baft
# Processing Record 33 of Set 13 | tilichiki
# Processing Record 34 of Set 13 | dawlatabad
# Processing Record 35 of Set 13 | sangar
# Processing Record 36 of Set 13 | krasnoselkup
# Processing Record 37 of Set 13 | mayahi
# Processing Record 38 of Set 13 | fortuna
# Processing Record 39 of Set 13 | bulgan
# Processing Record 40 of Set 13 | salalah
# Processing Record 41 of Set 13 | bulqize
# Processing Record 42 of Set 13 | mecca
# Processing Record 43 of Set 13 | lakatoro
# Processing Record 44 of Set 13 | eureka
# Processing Record 45 of Set 13 | santiago del estero
# Processing Record 46 of Set 13 | liberal
# Processing Record 47 of Set 13 | marawi
# Processing Record 48 of Set 13 | haines junction
# Processing Record 49 of Set 13 | merrill
# Processing Record 50 of Set 13 | cururupu
# Processing Record 1 of Set 14 | kaeo
# Processing Record 2 of Set 14 | fallon
# Processing Record 3 of Set 14 | san juan
# Processing Record 4 of Set 14 | mumbwa
# Processing Record 5 of Set 14 | havre-saint-pierre
# Processing Record 6 of Set 14 | karratha
# Processing Record 7 of Set 14 | grindavik
# Processing Record 8 of Set 14 | kirkland lake
# Processing Record 9 of Set 14 | coolum beach
# Processing Record 10 of Set 14 | suntar
# Processing Record 11 of Set 14 | nogliki
# Processing Record 12 of Set 14 | acapulco
# Processing Record 13 of Set 14 | pecos
# Processing Record 14 of Set 14 | yarada
# Processing Record 15 of Set 14 | kloulklubed
# Processing Record 16 of Set 14 | la roda
# Processing Record 17 of Set 14 | gao
# Processing Record 18 of Set 14 | torit
# Processing Record 19 of Set 14 | rayadrug
# Processing Record 20 of Set 14 | haradok
# Processing Record 21 of Set 14 | rafsanjan
# Processing Record 22 of Set 14 | gornozavodsk
# Processing Record 23 of Set 14 | san luis
# Processing Record 24 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 14 | cervo
# Processing Record 26 of Set 14 | binzhou
# Processing Record 27 of Set 14 | joshimath
# Processing Record 28 of Set 14 | alexandria
# Processing Record 29 of Set 14 | shu
# Processing Record 30 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 31 of Set 14 | obidos
# Processing Record 32 of Set 14 | beyneu
# Processing Record 33 of Set 14 | rudnogorsk
# Processing Record 34 of Set 14 | salym
# Processing Record 35 of Set 14 | itoman
# Processing Record 36 of Set 14 | lewistown
# Processing Record 37 of Set 14 | bontang
# Processing Record 38 of Set 14 | gorontalo
# Processing Record 39 of Set 14 | uvarovo
# Processing Record 40 of Set 14 | padre paraiso
# Processing Record 41 of Set 14 | la ronge
# Processing Record 42 of Set 14 | kieta
# Processing Record 43 of Set 14 | skovorodino
# Processing Record 44 of Set 14 | celestun
# Processing Record 45 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 14 | broome
# Processing Record 47 of Set 14 | shache
# Processing Record 48 of Set 14 | lucapa
# Processing Record 49 of Set 14 | slyudyanka
# Processing Record 50 of Set 14 | atar
# Processing Record 1 of Set 15 | pouembout
# Processing Record 2 of Set 15 | nadym
# Processing Record 3 of Set 15 | moindou
# Processing Record 4 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 5 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 15 | hede
# Processing Record 7 of Set 15 | barranca
# Processing Record 8 of Set 15 | baherden
# Processing Record 9 of Set 15 | eyl
# Processing Record 10 of Set 15 | valparaiso
# Processing Record 11 of Set 15 | hualmay
# Processing Record 12 of Set 15 | huarmey
# Processing Record 13 of Set 15 | safranbolu
# Processing Record 14 of Set 15 | kasama
# Processing Record 15 of Set 15 | hambantota
# Processing Record 16 of Set 15 | nishihara
# Processing Record 17 of Set 15 | paamiut
# Processing Record 18 of Set 15 | arman
# Processing Record 19 of Set 15 | moose factory
# Processing Record 20 of Set 15 | meulaboh
# Processing Record 21 of Set 15 | timizart
# Processing Record 22 of Set 15 | bambanglipuro
# Processing Record 23 of Set 15 | mahibadhoo
# Processing Record 24 of Set 15 | krasnogorskoye
# Processing Record 25 of Set 15 | vilhena
# Processing Record 26 of Set 15 | kidal
# Processing Record 27 of Set 15 | chapais
# Processing Record 28 of Set 15 | poso
# Processing Record 29 of Set 15 | jiamusi
# Processing Record 30 of Set 15 | canning
# Processing Record 31 of Set 15 | okha
# Processing Record 32 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 33 of Set 15 | grevena
# Processing Record 34 of Set 15 | taltal
# Processing Record 35 of Set 15 | namyslow
# Processing Record 36 of Set 15 | sao luiz gonzaga
# Processing Record 37 of Set 15 | siyabuswa
# Processing Record 38 of Set 15 | grand-santi
# Processing Record 39 of Set 15 | nhulunbuy
# Processing Record 40 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 15 | wukari
# Processing Record 42 of Set 15 | college
# Processing Record 43 of Set 15 | san cristobal
# Processing Record 44 of Set 15 | ponyri
# Processing Record 45 of Set 15 | merauke
# Processing Record 46 of Set 15 | menongue
# Processing Record 47 of Set 15 | acara
# Processing Record 48 of Set 15 | ardakan
# Processing Record 49 of Set 15 | samarai
# Processing Record 50 of Set 15 | balkhash
# Processing Record 1 of Set 16 | burnie
# Processing Record 2 of Set 16 | puerto del rosario
# Processing Record 3 of Set 16 | natitingou
# Processing Record 4 of Set 16 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 16 | salisbury
# Processing Record 6 of Set 16 | kaa-khem
# Processing Record 7 of Set 16 | sovetskiy
# Processing Record 8 of Set 16 | lixourion
# Processing Record 9 of Set 16 | lokosovo
# Processing Record 10 of Set 16 | synya
# Processing Record 11 of Set 16 | izhma
# Processing Record 12 of Set 16 | lexington
# Processing Record 13 of Set 16 | voyvozh
# Processing Record 14 of Set 16 | hammerfest
# Processing Record 15 of Set 16 | lai
# Processing Record 16 of Set 16 | mogocha
# Processing Record 17 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 16 | kimbe
# Processing Record 19 of Set 16 | escarcega
# Processing Record 20 of Set 16 | riyadh
# Processing Record 21 of Set 16 | karatsu
# Processing Record 22 of Set 16 | pereira barreto
# Processing Record 23 of Set 16 | maragogi
# Processing Record 24 of Set 16 | pag
# Processing Record 25 of Set 16 | manuk mangkaw
# Processing Record 26 of Set 16 | mulege
# Processing Record 27 of Set 16 | alekseyevsk
# Processing Record 28 of Set 16 | artyk
# City not found. Skipping...
# Processing Record 29 of Set 16 | cootamundra
# Processing Record 30 of Set 16 | spasskoye
# Processing Record 31 of Set 16 | devonport
# Processing Record 32 of Set 16 | indianola
# Processing Record 33 of Set 16 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 16 | aden
# Processing Record 35 of Set 16 | bonfim
# Processing Record 36 of Set 16 | te anau
# Processing Record 37 of Set 16 | vredendal
# Processing Record 38 of Set 16 | namatanai
# Processing Record 39 of Set 16 | shelburne
# Processing Record 40 of Set 16 | santo andre
# Processing Record 41 of Set 16 | inderborskiy
# City not found. Skipping...
# Processing Record 42 of Set 16 | sabya
# Processing Record 43 of Set 16 | marienburg
# Processing Record 44 of Set 16 | turayf
# Processing Record 45 of Set 16 | la ligua
# Processing Record 46 of Set 16 | savonlinna
# Processing Record 47 of Set 16 | omsukchan
# Processing Record 48 of Set 16 | piopio
# Processing Record 49 of Set 16 | zaranj
# Processing Record 50 of Set 16 | isla mujeres
# Processing Record 1 of Set 17 | harrison
# Processing Record 2 of Set 17 | bandarbeyla
# Processing Record 3 of Set 17 | kendari
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 743

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Butaritari   3.0707  172.7902     81.16        76          78
# 1         Gigmoto  13.7796  124.3900     82.71        79          92
# 2         Aklavik  68.2191 -135.0107    -15.88        97          92
# 3       Busselton -33.6500  115.3333     85.75        36           0
# 4  Cabo San Lucas  22.8909 -109.9124     70.52        70          60
# 5   Prince Rupert  54.3161 -130.3201     44.29        77         100
# 6  Port Elizabeth -33.9180   25.5701     69.10        67          40
# 7       Hithadhoo  -0.6000   73.0833     80.10        74          42
# 8        Monrovia   6.3005  -10.7969     75.79        88          48
# 9   Makakilo City  21.3469 -158.0858     75.52        71         100
#
#    Wind Speed Country Weather Description
# 0       12.77      KI       broken clouds
# 1        3.09      PH     overcast clouds
# 2        5.41      CA     overcast clouds
# 3       13.04      AU           clear sky
# 4        5.01      MX       broken clouds
# 5       20.71      CA     overcast clouds
# 6        5.75      ZA    scattered clouds
# 7        4.18      MV    scattered clouds
# 8        4.27      LR          light rain
# 9        3.44      US     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df = city_data_df.rename(columns={"Weather Description":"Current Description"})
new_city_data = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
new_city_df = city_data_df[new_city_data]

# Display sample data
new_city_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Butaritari      KI   3.0707  172.7902     81.16        76          78
# 1         Gigmoto      PH  13.7796  124.3900     82.71        79          92
# 2         Aklavik      CA  68.2191 -135.0107    -15.88        97          92
# 3       Busselton      AU -33.6500  115.3333     85.75        36           0
# 4  Cabo San Lucas      MX  22.8909 -109.9124     70.52        70          60
#
#    Wind Speed Current Description
# 0       12.77       broken clouds
# 1        3.09     overcast clouds
# 2        5.41     overcast clouds
# 3       13.04           clear sky
# 4        5.01       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
new_city_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
new_city_df.to_csv(output_file, index_label = "City_ID")
